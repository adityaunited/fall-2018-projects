# %%
import pandas as pd
import statsmodels.formula.api as smf

# %%
race4= pd.read_csv('2014.csv', na_values=['---','0'])
race4.head()
# Out:
#                name  genderRank  divRank overallRank  bib division   age  \
# 0  Sebastian Kienle         1.0      1.0           1    3      PRO  32.0
# 1       Ben Hoffman         2.0      2.0           2   41      PRO  33.0
# 2       Jan Frodeno         3.0      3.0           3    9      PRO  35.0
# 3        Andy Potts         4.0      4.0           4   15      PRO  39.0
# 4     Cyril Viennot         5.0      5.0           5   38      PRO  34.0
#
#   state country  profession     ...             t1      bike  bike_time  \
# 0   NaN     DEU         NaN     ...       00:02:01  04:20:46       4.35
# 1    CO     USA         NaN     ...       00:01:55  04:32:20       4.54
# 2   NaN     DEU         NaN     ...       00:01:51  04:37:19       4.62
# 3    CO     USA         NaN     ...       00:01:50  04:36:56       4.62
# 4   NaN     FRA         NaN     ...       00:01:57  04:31:18       4.52
#
#   bikeDistance        t2       run  run_time runDistance   overall  \
# ...

# %%
race4.describe()
# Out:
#         genderRank     divRank          bib          age  profession  \
# count  1985.000000  1985.00000  2187.000000  2186.000000         0.0
# mean    589.249874    71.20403  1148.963877    44.834401         NaN
# std     406.720016    62.20589   637.065283    11.407454         NaN
# min       1.000000     1.00000     1.000000    19.000000         NaN
# 25%     249.000000    22.00000   600.500000    37.000000         NaN
# 50%     497.000000    52.00000  1150.000000    44.000000         NaN
# 75%     925.000000   106.00000  1699.500000    52.000000         NaN
# max    1421.000000   271.00000  2248.000000    86.000000         NaN
#
#             points    swim_time    bike_time     run_time  overall_time
# count  1985.000000  2108.000000  2058.000000  1985.000000   1985.000000
# mean   3647.421662     1.264910     6.022575     4.168972     11.593673
# std     989.907045     0.254254     0.903202     0.863957      1.868554
# ...

# %%
race4.keys()
# Out:
# Index(['name', 'genderRank', 'divRank', 'overallRank', 'bib', 'division',
#        'age', 'state', 'country', 'profession', 'points', 'swim', 'swim_time',
#        'swimDistance', 't1', 'bike', 'bike_time', 'bikeDistance', 't2', 'run',
#        'run_time', 'runDistance', 'overall', 'overall_time'],
#       dtype='object')

# %%
reg='overall_time~bike_time+swim_time+run_time+age'
model=smf.ols(formula= reg, data=race4)
model.fit()
print(model.fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           overall_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 8.672e+05
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:12:56   Log-Likelihood:                 3356.0
# No. Observations:                1985   AIC:                            -6702.
# Df Residuals:                    1980   BIC:                            -6674.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1638      0.007    -23.227      0.000      -0.178      -0.150
# ...

# %%
race5= pd.read_csv('2015.csv', na_values=['---','0'])
race5.head()
# Out:
#                 name  genderRank  divRank overallRank  bib division   age  \
# 0        Jan Frodeno         1.0      1.0           1    2      PRO  35.0
# 1    Andreas Raelert         2.0      2.0           2   35      PRO  40.0
# 2      Tim O'Donnell         3.0      3.0           3   21      PRO  35.0
# 3         Andy Potts         4.0      4.0           4    5      PRO  39.0
# 4  Tyler Butterfield         5.0      5.0           5   29      PRO  33.0
#
#   state country  profession     ...             t1      bike  bike_time  \
# 0   NaN     DEU         NaN     ...       00:01:51  04:27:27       4.46
# 1   NaN     DEU         NaN     ...       00:01:56  04:30:52       4.51
# 2    CO     USA         NaN     ...       00:02:01  04:26:13       4.44
# 3    CO     USA         NaN     ...       00:01:43  04:32:41       4.54
# 4    CO     BMU         NaN     ...       00:02:01  04:29:35       4.49
#
#   bikeDistance        t2       run  run_time runDistance   overall  \
# ...

# %%
race5.describe()
# Out:
#         genderRank      divRank          bib          age  profession  \
# count  2143.000000  2143.000000  2308.000000  2284.000000         0.0
# mean    642.645824    77.525898  1239.657712    43.582312         NaN
# std     445.479063    67.360966   689.431434    11.183915         NaN
# min       1.000000     1.000000     1.000000    20.000000         NaN
# 25%     268.500000    24.000000   644.750000    35.000000         NaN
# 50%     536.000000    56.000000  1241.500000    43.000000         NaN
# 75%    1013.500000   118.000000  1838.250000    51.000000         NaN
# max    1549.000000   283.000000  2425.000000    86.000000         NaN
#
#             points    swim_time    bike_time     run_time  overall_time
# count  2144.000000  2296.000000  2241.000000  2143.000000   2143.000000
# mean   3550.805504     1.278611     5.899121     4.373929     11.705791
# std    1007.828657     0.248500     0.826615     0.912766      1.806772
# ...

# %%
race5.keys()
# Out:
# Index(['name', 'genderRank', 'divRank', 'overallRank', 'bib', 'division',
#        'age', 'state', 'country', 'profession', 'points', 'swim', 'swim_time',
#        'swimDistance', 't1', 'bike', 'bike_time', 'bikeDistance', 't2', 'run',
#        'run_time', 'runDistance', 'overall', 'overall_time'],
#       dtype='object')

# %%
reg='overall_time~bike_time+swim_time+run_time+age'
model=smf.ols(formula= reg, data=race5)
model.fit()
print(model.fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           overall_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.232e+05
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:12:57   Log-Likelihood:                 2825.6
# No. Observations:                2120   AIC:                            -5641.
# Df Residuals:                    2115   BIC:                            -5613.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2252      0.011    -21.344      0.000      -0.246      -0.205
# ...

# %%
race3= pd.read_csv('2013.csv', na_values=['---', '#VALUE!'])
race3.head()
# Out:
#                   name  genderRank  divRank overallRank  bib division   age  \
# 0  Frederik Van Lierde         1.0      1.0           1    6      PRO  37.0
# 1        Luke Mckenzie         2.0      2.0           2   49      PRO  35.0
# 2     Sebastian Kienle         3.0      3.0           3    2      PRO  32.0
# 3        James Cunnama         4.0      4.0           4   55      PRO  33.0
# 4        Tim O'Donnell         5.0      5.0           5    7      PRO  35.0
#
#         state country  profession     ...             t1      bike  bike_time  \
# 0         NaN     BEL         NaN     ...       00:02:18  04:25:35     4.4264
# 1          CA     AUS         NaN     ...       00:01:59  04:22:25     4.3736
# 2         NaN     DEU         NaN     ...       00:01:49  04:22:33     4.3758
# 3  Intl State     ZAF         NaN     ...       00:01:45  04:34:21     4.5725
# 4          CO     USA         NaN     ...       00:02:05  04:35:37     4.5936
#
# ...

# %%
race3.describe()
# Out:
#         genderRank      divRank          bib          age  profession  \
# count  1973.000000  1973.000000  2134.000000  2115.000000         0.0
# mean    603.106437    74.293462  1123.503749    45.104965         NaN
# std     420.843794    66.504736   622.280685    11.067452         NaN
# min       1.000000     1.000000     1.000000     3.000000         NaN
# 25%     247.000000    22.000000   588.250000    37.000000         NaN
# 50%     494.000000    51.000000  1124.500000    44.000000         NaN
# 75%     958.000000   115.000000  1660.750000    52.000000         NaN
# max    1451.000000   282.000000  2198.000000    83.000000         NaN
#
#             points    swim_time    bike_time     run_time  overall_time
# count  1973.000000  2063.000000  2038.000000  1976.000000   1973.000000
# mean   3703.159149     1.200276     5.610132     4.153882     11.106192
# std     968.320176     0.219607     0.757288     0.914798      1.741499
# ...

# %%
reg='overall_time~bike_time+swim_time+run_time+age'
model=smf.ols(formula= reg, data=race3)
model.fit()
print(model.fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           overall_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 5.203e+05
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:12:57   Log-Likelihood:                 2969.6
# No. Observations:                1958   AIC:                            -5929.
# Df Residuals:                    1953   BIC:                            -5901.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1896      0.010    -19.693      0.000      -0.208      -0.171
# ...

# %%
race2= pd.read_csv('2012.csv', na_values=['---', '#VALUE!'])
race2.head()
# Out:
#                   name  genderRank  divRank overallRank  bib division   age  \
# 0          Pete Jacobs         1.0      1.0           1    3      PRO  34.0
# 1      Andreas Raelert         2.0      2.0           2    2      PRO  40.0
# 2  Frederik Van Lierde         3.0      3.0           3   16      PRO  37.0
# 3     Sebastian Kienle         4.0      4.0           4    6      PRO  32.0
# 4      Faris Al-Sultan         5.0      5.0           5   15      PRO  38.0
#
#   state country  profession     ...             t1      bike  bike_time  \
# 0   QLD     AUS         NaN     ...       00:01:48  04:35:15     4.5875
# 1   NaN     DEU         NaN     ...       00:01:53  04:36:34     4.6094
# 2   NaN     BEL         NaN     ...       00:02:00  04:35:25     4.5903
# 3   NaN     DEU         NaN     ...       00:01:55  04:33:23     4.5564
# 4    DE     ARE         NaN     ...       00:01:45  04:35:53     4.5981
#
#   bikeDistance        t2       run  run_time runDistance   overall  \
# ...

# %%
reg='overall_time~bike_time+swim_time+run_time+age'
model=smf.ols(formula= reg, data=race2)
model.fit()
print(model.fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           overall_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 6.470e+05
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:12:58   Log-Likelihood:                 3011.6
# No. Observations:                1872   AIC:                            -6013.
# Df Residuals:                    1867   BIC:                            -5986.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2463      0.009    -26.436      0.000      -0.265      -0.228
# ...

# %%
race2.describe()
# Out:
#         genderRank      divRank          bib          age  profession  \
# count  1887.000000  1887.000000  2038.000000  2023.000000         0.0
# mean    565.065183    66.765236  1070.644259    46.322788         NaN
# std     391.433607    58.389871   593.243440    11.349545         NaN
# min       1.000000     1.000000     1.000000    22.000000         NaN
# 25%     236.500000    20.500000   560.250000    38.000000         NaN
# 50%     472.000000    48.000000  1071.500000    45.000000         NaN
# 75%     890.500000    99.500000  1582.750000    53.000000         NaN
# max    1362.000000   243.000000  2095.000000    86.000000         NaN
#
#             points    swim_time    bike_time     run_time  overall_time
# count  1887.000000  1984.000000  1952.000000  1887.000000   1887.000000
# mean   3703.685745     1.244035     5.897413     4.239104     11.541383
# std     964.064509     0.242213     0.759769     0.933652      1.804528
# ...

# %%
race1= pd.read_csv('2011.csv', na_values=['---','#VALUE!'])
race1.head()
# Out:
#               name  genderRank  divRank overallRank  bib division   age state  \
# 0  Craig Alexander         1.0      1.0           1    1      PRO  43.0   NSW
# 1      Pete Jacobs         2.0      2.0           2   11      PRO  34.0   QLD
# 2  Andreas Raelert         3.0      3.0           3   10      PRO  40.0   NaN
# 3      Dirk Bockel         4.0      4.0           4   33      PRO  39.0    FL
# 4      Timo Bracht         5.0      5.0           5    9      PRO  41.0   NaN
#
#   country  profession     ...             t1      bike  bike_time  \
# 0     AUS         NaN     ...       00:01:55  04:24:05       4.40
# 1     AUS         NaN     ...       00:01:57  04:31:01       4.52
# 2     DEU         NaN     ...       00:02:04  04:26:52       4.45
# 3     LUX         NaN     ...       00:02:00  04:24:17       4.40
# 4     DEU         NaN     ...       00:01:42  04:35:07       4.59
#
#   bikeDistance        t2       run  run_time runDistance   overall  \
# ...

# %%
race1.describe()
# Out:
#         genderRank      divRank          bib          age  profession  points  \
# count  1774.000000  1774.000000  1918.000000  1898.000000         0.0     0.0
# mean    539.195603    69.672492  1008.811783    46.476818         NaN     NaN
# std     375.551691    63.067367   556.556201    10.771736         NaN     NaN
# min       1.000000     1.000000     1.000000    16.000000         NaN     NaN
# 25%     222.250000    19.000000   530.250000    39.000000         NaN     NaN
# 50%     444.000000    48.500000  1010.500000    45.000000         NaN     NaN
# 75%     854.750000   106.000000  1489.750000    53.000000         NaN     NaN
# max    1298.000000   262.000000  1969.000000    86.000000         NaN     NaN
#
#          swim_time    bike_time     run_time  overall_time
# count  1855.000000  1832.000000  1775.000000   1774.000000
# mean      1.238938     5.707424     4.135234     11.240727
# std       0.238178     0.748287     0.906719      1.762350
# ...

# %%
reg='overall_time~bike_time+swim_time+run_time+age'
model=smf.ols(formula= reg, data=race1)
model.fit()
print(model.fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           overall_time   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.897e+05
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:12:59   Log-Likelihood:                 2672.6
# No. Observations:                1757   AIC:                            -5335.
# Df Residuals:                    1752   BIC:                            -5308.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2225      0.010    -21.351      0.000      -0.243      -0.202
# ...
